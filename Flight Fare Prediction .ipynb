# %% [markdown]
# # 1) Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style = 'whitegrid')

# %% [markdown]
# # 2) Reading Data

# %%
data = pd.read_excel('Data_Train.xlsx')
Test = pd.read_excel('Test_set.xlsx')

# %%
data.shape
# Out:
# (10683, 11)

# %%
Test.shape
# Out:
# (2671, 10)

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
data.tail()
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10678              CCU → BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# # 3 ) Hanlding Nulls

# %%
data.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
for n,i in enumerate(data['Route'].isna().values) : 
    if i == True : print(n)
# Out:
# 9039

# %%
missing = np.where(data["Route"].isnull() == True)
missing
# Out:
# (array([9039], dtype=int64),)

# %%
data.loc[9039,:]
# Out:
# Airline               Air India
# Date_of_Journey       6/05/2019
# Source                    Delhi
# Destination              Cochin
# Route                       NaN
# Dep_Time                  09:45
# Arrival_Time       09:25 07 May
# Duration                23h 40m
# Total_Stops                 NaN
# Additional_Info         No info
# Price                      7480
# Name: 9039, dtype: object

# %%
data.drop([9039],axis=0,inplace=True)

# %%
for n,i in enumerate(data['Route'].isna().values) : 
    if i == True : print(n)

# %%
data.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
data.reset_index(inplace=True)
data.drop(['index'],axis=1,inplace=True)

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10677     Air Asia       9/04/2019   Kolkata    Banglore
# 10678    Air India      27/04/2019   Kolkata    Banglore
# 10679  Jet Airways      27/04/2019  Banglore       Delhi
# 10680      Vistara      01/03/2019  Banglore   New Delhi
# 10681    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10677              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10678              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10679              BLR → DEL    08:20         11:20       3h    non-stop
# 10680              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10681  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10677         No info   4107
# 10678         No info   4145
# 10679         No info   7229
# 10680         No info  12648
# 10681         No info  11753
#
# [10682 rows x 11 columns]

# %% [markdown]
# # 4) Data Processing

# %%
def ShowDetails():
    global data
    for col in data.columns : 
        print(f'for feature {col}')
        print(f'Number of Nulls is {data[col].isna().sum()}')
        print(f'Number of Unique Values is {len(data[col].unique())}')
        print(f'Unique Values is {data[col].unique()}')
        print(f'Random Value is {data[col][np.random.randint(data.shape[0])]}')
        print(f'Random Value is {data[col][np.random.randint(data.shape[0])]}')
        print(f'Random Value is {data[col][np.random.randint(data.shape[0])]}')
        print('\n\n==================================\n\n')

# %%
ShowDetails()
# Out:
# for feature Airline
# Number of Nulls is 0
# Number of Unique Values is 12
# Unique Values is ['IndiGo' 'Air India' 'Jet Airways' 'SpiceJet' 'Multiple carriers' 'GoAir'
#  'Vistara' 'Air Asia' 'Vistara Premium economy' 'Jet Airways Business'
#  'Multiple carriers Premium economy' 'Trujet']
# Random Value is Air India
# Random Value is SpiceJet
# Random Value is Air Asia
#
#
# ==================================
#
#
# for feature Date_of_Journey
# Number of Nulls is 0
# Number of Unique Values is 44
# Unique Values is ['24/03/2019' '1/05/2019' '9/06/2019' '12/05/2019' '01/03/2019'
#  '24/06/2019' '12/03/2019' '27/05/2019' '1/06/2019' '18/04/2019'
#  '9/05/2019' '24/04/2019' '3/03/2019' '15/04/2019' '12/06/2019'
#  '6/03/2019' '21/03/2019' '3/04/2019' '6/05/2019' '15/05/2019'
#  '18/06/2019' '15/06/2019' '6/04/2019' '18/05/2019' '27/06/2019'
#  '21/05/2019' '06/03/2019' '3/06/2019' '15/03/2019' '3/05/2019'
#  '9/03/2019' '6/06/2019' '24/05/2019' '09/03/2019' '1/04/2019'
#  '21/04/2019' '21/06/2019' '27/03/2019' '18/03/2019' '12/04/2019'
#  '9/04/2019' '1/03/2019' '03/03/2019' '27/04/2019']
# Random Value is 27/05/2019
# Random Value is 24/05/2019
# Random Value is 6/06/2019
#
#
# ==================================
#
#
# for feature Source
# Number of Nulls is 0
# Number of Unique Values is 5
# Unique Values is ['Banglore' 'Kolkata' 'Delhi' 'Chennai' 'Mumbai']
# Random Value is Mumbai
# Random Value is Kolkata
# Random Value is Banglore
#
#
# ==================================
#
#
# for feature Destination
# Number of Nulls is 0
# Number of Unique Values is 6
# Unique Values is ['New Delhi' 'Banglore' 'Cochin' 'Kolkata' 'Delhi' 'Hyderabad']
# Random Value is Cochin
# Random Value is Cochin
# Random Value is Banglore
#
#
# ==================================
#
#
# for feature Route
# Number of Nulls is 0
# Number of Unique Values is 128
# Unique Values is ['BLR → DEL' 'CCU → IXR → BBI → BLR' 'DEL → LKO → BOM → COK'
#  'CCU → NAG → BLR' 'BLR → NAG → DEL' 'CCU → BLR' 'BLR → BOM → DEL'
#  'DEL → BOM → COK' 'DEL → BLR → COK' 'MAA → CCU' 'CCU → BOM → BLR'
#  'DEL → AMD → BOM → COK' 'DEL → PNQ → COK' 'DEL → CCU → BOM → COK'
#  'BLR → COK → DEL' 'DEL → IDR → BOM → COK' 'DEL → LKO → COK'
#  'CCU → GAU → DEL → BLR' 'DEL → NAG → BOM → COK' 'CCU → MAA → BLR'
#  'DEL → HYD → COK' 'CCU → HYD → BLR' 'DEL → COK' 'CCU → DEL → BLR'
#  'BLR → BOM → AMD → DEL' 'BOM → DEL → HYD' 'DEL → MAA → COK' 'BOM → HYD'
#  'DEL → BHO → BOM → COK' 'DEL → JAI → BOM → COK' 'DEL → ATQ → BOM → COK'
#  'DEL → JDH → BOM → COK' 'CCU → BBI → BOM → BLR' 'BLR → MAA → DEL'
#  'DEL → GOI → BOM → COK' 'DEL → BDQ → BOM → COK' 'CCU → JAI → BOM → BLR'
#  'CCU → BBI → BLR' 'BLR → HYD → DEL' 'DEL → TRV → COK'
#  'CCU → IXR → DEL → BLR' 'DEL → IXU → BOM → COK' 'CCU → IXB → BLR'
#  'BLR → BOM → JDH → DEL' 'DEL → UDR → BOM → COK' 'DEL → HYD → MAA → COK'
#  'CCU → BOM → COK → BLR' 'BLR → CCU → DEL' 'CCU → BOM → GOI → BLR'
#  'DEL → RPR → NAG → BOM → COK' 'DEL → HYD → BOM → COK'
#  'CCU → DEL → AMD → BLR' 'CCU → PNQ → BLR' 'BLR → CCU → GAU → DEL'
#  'CCU → DEL → COK → BLR' 'BLR → PNQ → DEL' 'BOM → JDH → DEL → HYD'
#  'BLR → BOM → BHO → DEL' 'DEL → AMD → COK' 'BLR → LKO → DEL'
#  'CCU → GAU → BLR' 'BOM → GOI → HYD' 'CCU → BOM → AMD → BLR'
#  'CCU → BBI → IXR → DEL → BLR' 'DEL → DED → BOM → COK'
#  'DEL → MAA → BOM → COK' 'BLR → AMD → DEL' 'BLR → VGA → DEL'
#  'CCU → JAI → DEL → BLR' 'CCU → AMD → BLR' 'CCU → VNS → DEL → BLR'
#  'BLR → BOM → IDR → DEL' 'BLR → BBI → DEL' 'BLR → GOI → DEL'
#  'BOM → AMD → ISK → HYD' 'BOM → DED → DEL → HYD' 'DEL → IXC → BOM → COK'
#  'CCU → PAT → BLR' 'BLR → CCU → BBI → DEL' 'CCU → BBI → HYD → BLR'
#  'BLR → BOM → NAG → DEL' 'BLR → CCU → BBI → HYD → DEL' 'BLR → GAU → DEL'
#  'BOM → BHO → DEL → HYD' 'BOM → JLR → HYD' 'BLR → HYD → VGA → DEL'
#  'CCU → KNU → BLR' 'CCU → BOM → PNQ → BLR' 'DEL → BBI → COK'
#  'BLR → VGA → HYD → DEL' 'BOM → JDH → JAI → DEL → HYD'
#  'DEL → GWL → IDR → BOM → COK' 'CCU → RPR → HYD → BLR' 'CCU → VTZ → BLR'
#  'CCU → DEL → VGA → BLR' 'BLR → BOM → IDR → GWL → DEL'
#  'CCU → DEL → COK → TRV → BLR' 'BOM → COK → MAA → HYD' 'BOM → NDC → HYD'
#  'BLR → BDQ → DEL' 'CCU → BOM → TRV → BLR' 'CCU → BOM → HBX → BLR'
#  'BOM → BDQ → DEL → HYD' 'BOM → CCU → HYD' 'BLR → TRV → COK → DEL'
#  'BLR → IDR → DEL' 'CCU → IXZ → MAA → BLR' 'CCU → GAU → IMF → DEL → BLR'
#  'BOM → GOI → PNQ → HYD' 'BOM → BLR → CCU → BBI → HYD' 'BOM → MAA → HYD'
#  'BLR → BOM → UDR → DEL' 'BOM → UDR → DEL → HYD' 'BLR → VGA → VTZ → DEL'
#  'BLR → HBX → BOM → BHO → DEL' 'CCU → IXA → BLR' 'BOM → RPR → VTZ → HYD'
#  'BLR → HBX → BOM → AMD → DEL' 'BOM → IDR → DEL → HYD' 'BOM → BLR → HYD'
#  'BLR → STV → DEL' 'CCU → IXB → DEL → BLR' 'BOM → JAI → DEL → HYD'
#  'BOM → VNS → DEL → HYD' 'BLR → HBX → BOM → NAG → DEL'
#  'BLR → BOM → IXC → DEL' 'BLR → CCU → BBI → HYD → VGA → DEL'
#  'BOM → BBI → HYD']
# Random Value is DEL → BOM → COK
# Random Value is BLR → DEL
# Random Value is DEL → BOM → COK
#
#
# ==================================
#
#
# for feature Dep_Time
# Number of Nulls is 0
# Number of Unique Values is 222
# Unique Values is ['22:20' '05:50' '09:25' '18:05' '16:50' '09:00' '18:55' '08:00' '08:55'
#  '11:25' '09:45' '20:20' '11:40' '21:10' '17:15' '16:40' '08:45' '14:00'
#  '20:15' '16:00' '14:10' '22:00' '04:00' '21:25' '21:50' '07:00' '07:05'
#  '09:50' '14:35' '10:35' '15:05' '14:15' '06:45' '20:55' '11:10' '05:45'
#  '19:00' '23:05' '11:00' '09:35' '21:15' '23:55' '19:45' '08:50' '15:40'
#  '06:05' '15:00' '13:55' '05:55' '13:20' '05:05' '06:25' '17:30' '08:20'
#  '19:55' '06:30' '14:05' '02:00' '09:40' '08:25' '20:25' '13:15' '02:15'
#  '16:55' '20:45' '05:15' '19:50' '20:00' '06:10' '19:30' '04:45' '12:55'
#  '18:15' '17:20' '15:25' '23:00' '12:00' '14:45' '11:50' '11:30' '14:40'
#  '19:10' '06:00' '23:30' '07:35' '13:05' '12:30' '15:10' '12:50' '18:25'
#  '16:30' '00:40' '06:50' '13:00' '19:15' '01:30' '17:00' '10:00' '19:35'
#  '15:30' '12:10' '16:10' '20:35' '22:25' '21:05' '05:35' '05:10' '06:40'
#  '15:15' '00:30' '08:30' '07:10' '05:30' '14:25' '05:25' '10:20' '17:45'
#  '13:10' '22:10' '04:55' '17:50' '21:20' '06:20' '15:55' '20:30' '17:25'
#  '09:30' '07:30' '02:35' '10:55' '17:10' '09:10' '18:45' '15:20' '22:50'
#  '14:55' '14:20' '13:25' '22:15' '11:05' '16:15' '20:10' '06:55' '19:05'
#  '07:55' '07:45' '10:10' '08:15' '11:35' '21:00' '17:55' '16:45' '18:20'
#  '03:50' '08:35' '19:20' '20:05' '17:40' '04:40' '17:35' '09:55' '05:00'
#  '18:00' '02:55' '20:40' '22:55' '22:40' '21:30' '08:10' '17:05' '07:25'
#  '15:45' '09:15' '15:50' '11:45' '22:05' '18:35' '00:25' '19:40' '20:50'
#  '22:45' '10:30' '23:25' '11:55' '10:45' '11:15' '12:20' '14:30' '07:15'
#  '01:35' '18:40' '09:20' '21:55' '13:50' '01:40' '00:20' '04:15' '13:45'
#  '18:30' '06:15' '02:05' '12:15' '13:30' '06:35' '10:05' '08:40' '03:05'
#  '21:35' '16:35' '02:30' '16:25' '05:40' '15:35' '13:40' '07:20' '04:50'
#  '12:45' '10:25' '12:05' '11:20' '21:40' '03:00']
# Random Value is 07:10
# Random Value is 07:05
# Random Value is 04:55
#
#
# ==================================
#
#
# for feature Arrival_Time
# Number of Nulls is 0
# Number of Unique Values is 1343
# Unique Values is ['01:10 22 Mar' '13:15' '04:25 10 Jun' ... '06:50 10 Mar' '00:05 19 Mar'
#  '21:20 13 Mar']
# Random Value is 21:05 13 May
# Random Value is 23:00
# Random Value is 19:00 07 Jun
#
#
# ==================================
#
#
# for feature Duration
# Number of Nulls is 0
# Number of Unique Values is 368
# Unique Values is ['2h 50m' '7h 25m' '19h' '5h 25m' '4h 45m' '2h 25m' '15h 30m' '21h 5m'
#  '25h 30m' '7h 50m' '13h 15m' '2h 35m' '2h 15m' '12h 10m' '26h 35m'
#  '4h 30m' '22h 35m' '23h' '20h 35m' '5h 10m' '15h 20m' '2h 55m' '13h 20m'
#  '15h 10m' '5h 45m' '5h 55m' '13h 25m' '22h' '5h 30m' '10h 25m' '5h 15m'
#  '2h 30m' '6h 15m' '11h 55m' '11h 5m' '8h 30m' '22h 5m' '2h 45m' '12h'
#  '16h 5m' '19h 55m' '3h 15m' '25h 20m' '3h' '16h 15m' '15h 5m' '6h 30m'
#  '25h 5m' '12h 25m' '27h 20m' '10h 15m' '10h 30m' '1h 30m' '1h 25m'
#  '26h 30m' '7h 20m' '13h 30m' '5h' '19h 5m' '14h 50m' '2h 40m' '22h 10m'
#  '9h 35m' '10h' '21h 20m' '18h 45m' '12h 20m' '18h' '9h 15m' '17h 30m'
#  '16h 35m' '12h 15m' '7h 30m' '24h' '8h 55m' '7h 10m' '14h 30m' '30h 20m'
#  '15h' '12h 45m' '10h 10m' '15h 25m' '14h 5m' '20h 15m' '23h 10m'
#  '22h 25m' '19h 35m' '25h' '26h 45m' '38h' '4h 15m' '25h 10m' '18h 15m'
#  '6h 50m' '23h 55m' '17h 55m' '23h 25m' '17h 10m' '24h 20m' '28h 30m'
#  '27h 10m' '19h 20m' '15h 35m' '9h 25m' '21h 30m' '34h 25m' '18h 35m'
#  '29h 40m' '26h 5m' '29h 5m' '27h 25m' '16h 30m' '11h 10m' '28h 55m'
#  '29h 10m' '34h' '30h 40m' '30h 45m' '32h 55m' '10h 5m' '35h 20m' '32h 5m'
#  '31h 40m' '19h 50m' '33h 45m' '30h 10m' '13h 40m' '19h 30m' '31h 30m'
#  '34h 30m' '27h 50m' '38h 35m' '42h 5m' '4h 10m' '39h 5m' '3h 50m' '5m'
#  '32h 30m' '31h 55m' '33h 20m' '27h 30m' '18h 55m' '9h 55m' '41h 20m'
#  '20h 5m' '31h 50m' '42h 45m' '3h 25m' '37h 10m' '29h 30m' '32h 20m'
#  '20h 50m' '40h 20m' '13h 35m' '47h 40m']
# Random Value is 27h 5m
# Random Value is 9h 35m
# Random Value is 19h 55m
#
#
# ==================================
#
#
# for feature Total_Stops
# Number of Nulls is 0
# Number of Unique Values is 5
# Unique Values is ['non-stop' '2 stops' '1 stop' '3 stops' '4 stops']
# Random Value is 2 stops
# Random Value is 2 stops
# Random Value is 1 stop
#
#
# ==================================
#
#
# for feature Additional_Info
# Number of Nulls is 0
# Number of Unique Values is 10
# Unique Values is ['No info' 'In-flight meal not included' 'No check-in baggage included'
#  '1 Short layover' 'No Info' '1 Long layover' 'Change airports'
#  'Business class' 'Red-eye flight' '2 Long layover']
# Random Value is No info
# Random Value is In-flight meal not included
# Random Value is No info
#
#
# ==================================
#
#
# for feature Price
# Number of Nulls is 0
# Number of Unique Values is 1870
# Unique Values is [ 3897  7662 13882 ...  9790 12352 12648]
# Random Value is 12557
# Random Value is 4174
# Random Value is 12284
#
#
# ==================================

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
data['DayOfJourney']=  data['Date_of_Journey'].apply(lambda x : x.split('/')[0])
data['MonthOfJourney']=  data['Date_of_Journey'].apply(lambda x : x.split('/')[1])
data['YearOfJourney']=  data['Date_of_Journey'].apply(lambda x : x.split('/')[2])
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#   DayOfJourney MonthOfJourney YearOfJourney
# 0           24             03          2019
# 1            1             05          2019
# 2            9             06          2019
# 3           12             05          2019
# 4           01             03          2019

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#   DayOfJourney MonthOfJourney YearOfJourney
# 0           24             03          2019
# 1            1             05          2019
# 2            9             06          2019
# 3           12             05          2019
# 4           01             03          2019

# %%
data['DayOfJourney'].unique()
# Out:
# array(['24', '1', '9', '12', '01', '27', '18', '3', '15', '6', '21', '06',
#        '09', '03'], dtype=object)

# %%
data['MonthOfJourney'].unique()
# Out:
# array(['03', '05', '06', '04'], dtype=object)

# %%
data['YearOfJourney'].unique()
# Out:
# array(['2019'], dtype=object)

# %%
data.drop(['YearOfJourney'],axis=1,inplace=True)

# %%
data['DayOfJourney'] = data['DayOfJourney'].astype(int)
data['MonthOfJourney'] = data['MonthOfJourney'].astype(int)

# %%
data['DayOfJourney'].unique()
# Out:
# array([24,  1,  9, 12, 27, 18,  3, 15,  6, 21])

# %%
data['MonthOfJourney'].unique()
# Out:
# array([3, 5, 6, 4])

# %%
set([len(i.split()) for i in data['Dep_Time'].tolist()])
# Out:
# {1}

# %%
pd.Series([len(i.split()) for i in data['Arrival_Time'].tolist()]).value_counts()
# Out:
# 1    6348
# 3    4334
# dtype: int64

# %%
set([str(i).count(":") for i in data['Arrival_Time'].tolist()])
# Out:
# {1}

# %%
len(data['Arrival_Time'].unique())
# Out:
# 1343

# %%
data['AccurateArrivalTime'] = data['Arrival_Time'].apply(lambda x : x.split()[0])

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10677     Air Asia       9/04/2019   Kolkata    Banglore
# 10678    Air India      27/04/2019   Kolkata    Banglore
# 10679  Jet Airways      27/04/2019  Banglore       Delhi
# 10680      Vistara      01/03/2019  Banglore   New Delhi
# 10681    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10677              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10678              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10679              BLR → DEL    08:20         11:20       3h    non-stop
# 10680              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10681  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price  DayOfJourney  MonthOfJourney AccurateArrivalTime
# 0             No info   3897            24               3               01:10
# 1             No info   7662             1               5               13:15
# 2             No info  13882             9               6               04:25
# 3             No info   6218            12               5               23:30
# 4             No info  13302             1               3               21:35
# ...               ...    ...           ...             ...                 ...
# 10677         No info   4107             9               4               22:25
# 10678         No info   4145            27               4               23:20
# 10679         No info   7229            27               4               11:20
# 10680         No info  12648             1               3               14:10
# 10681         No info  11753             9               5               19:15
#
# [10682 rows x 14 columns]

# %%
set([str(i).count(":") for i in data['AccurateArrivalTime'].tolist()])
# Out:
# {1}

# %%
# def GetArriveDate(n,Needed) : 
#     if len(n.split()) ==1 : 
#         return 'None'
#     else : 
#         if Needed == 'D' : 
#             return n.split()[1]
#         elif Needed == 'M' : 
#             return n.split()[2]
    

# data['AccurateArrivalDay'] = data['Arrival_Time'].apply(lambda x : GetArriveDate(x,'D'))
data['AccurateArrivalDay'] = data['Arrival_Time'].apply(lambda x : str(x).split()[1] if len(str(x).split()) ==3 else 'None')
data['AccurateArrivalMonth'] = data['Arrival_Time'].apply(lambda x : str(x).split()[2] if len(str(x).split()) ==3 else 'None')

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    DayOfJourney  MonthOfJourney AccurateArrivalTime AccurateArrivalDay  \
# 0            24               3               01:10                 22
# 1             1               5               13:15               None
# 2             9               6               04:25                 10
# 3            12               5               23:30               None
# 4             1               3               21:35               None
#
#   AccurateArrivalMonth
# 0                  Mar
# 1                 None
# 2                  Jun
# 3                 None
# 4                 None

# %%
data['AccurateArrivalDay'].unique()
# Out:
# array(['22', 'None', '10', '13', '02', '04', '28', '19', '07', '16', '25',
#        '20', '23', '11', '03', '08', '05', '26', '29', '17'], dtype=object)

# %%
data['AccurateArrivalMonth'].unique()
# Out:
# array(['Mar', 'None', 'Jun', 'May', 'Apr'], dtype=object)

# %%
def FindWrongData(DepDay,ArrivalDay) : 
    if ArrivalDay != 'None' : 
        if int(ArrivalDay) < int(DepDay) : 
            return True
        else : 
            return False 
    else : 
        return False
    
data['DayDifference']  = data.apply(lambda x : FindWrongData(x.DayOfJourney,x.AccurateArrivalDay),axis = 1)

# %%
data[['DayOfJourney','AccurateArrivalDay','DayDifference']]
# Out:
#        DayOfJourney AccurateArrivalDay  DayDifference
# 0                24                 22           True
# 1                 1               None          False
# 2                 9                 10          False
# 3                12               None          False
# 4                 1               None          False
# ...             ...                ...            ...
# 10677             9               None          False
# 10678            27               None          False
# 10679            27               None          False
# 10680             1               None          False
# 10681             9               None          False
#
# [10682 rows x 3 columns]

# %%
data['DayDifference'].value_counts()
# Out:
# False    10593
# True        89
# Name: DayDifference, dtype: int64

# %%
WrongIndices = data[data['DayDifference']==True].index
WrongIndices
# Out:
# Int64Index([    0,    21,   110,   379,   605,   628,  1115,  1268,  1318,
#              1354,  1478,  1538,  1721,  2010,  2089,  2095,  2108,  2353,
#              2364,  2537,  2568,  2588,  2618,  3170,  3247,  3301,  3639,
#              3836,  3913,  4053,  4120,  4428,  4476,  4615,  4624,  4723,
#              4764,  4839,  4913,  4948,  4953,  5067,  5130,  5133,  5214,
#              5419,  5464,  5545,  5591,  5803,  5814,  6154,  6173,  6239,
#              6436,  6494,  6677,  7146,  7337,  7507,  7527,  7584,  7612,
#              7738,  8000,  8068,  8182,  8603,  8934,  9197,  9320,  9452,
#              9514,  9555,  9688,  9843,  9929, 10003, 10120, 10150, 10244,
#             10323, 10342, 10367, 10440, 10488, 10589, 10637, 10659],
#            dtype='int64')

# %%
data.loc[WrongIndices,['MonthOfJourney','AccurateArrivalMonth']]
# Out:
#        MonthOfJourney AccurateArrivalMonth
# 0                   3                  Mar
# 21                  3                  Mar
# 110                 3                  Mar
# 379                 3                  Mar
# 605                 3                  Mar
# ...               ...                  ...
# 10440               3                  Mar
# 10488               3                  Mar
# 10589               3                  Mar
# 10637               3                  Mar
# 10659               3                  Mar
#
# [89 rows x 2 columns]

# %%
data.loc[WrongIndices,['MonthOfJourney','AccurateArrivalMonth']]['MonthOfJourney'].unique()
# Out:
# array([3, 4])

# %%
data.loc[WrongIndices,['MonthOfJourney','AccurateArrivalMonth']]['AccurateArrivalMonth'].unique()
# Out:
# array(['Mar', 'Apr'], dtype=object)

# %%
MonthsDict  = {3:'Mar',4:'Apr'}

# %%
for a,b in zip(data.loc[WrongIndices,['MonthOfJourney','AccurateArrivalMonth']]['MonthOfJourney'].tolist(),
               data.loc[WrongIndices,['MonthOfJourney','AccurateArrivalMonth']]['AccurateArrivalMonth'].tolist()) : 
    if MonthsDict[a] != b : 
        print(a)

# %%
data.drop(data[data['DayDifference']==True].index,axis=0,inplace=True)

# %%
data['DayDifference'].value_counts()
# Out:
# False    10593
# Name: DayDifference, dtype: int64

# %%
data.reset_index(inplace=True)
data.drop(['index'],axis=1,inplace=True)

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0        Air India       1/05/2019   Kolkata    Banglore
# 1      Jet Airways       9/06/2019     Delhi      Cochin
# 2           IndiGo      12/05/2019   Kolkata    Banglore
# 3           IndiGo      01/03/2019  Banglore   New Delhi
# 4         SpiceJet      24/06/2019   Kolkata    Banglore
# ...            ...             ...       ...         ...
# 10588     Air Asia       9/04/2019   Kolkata    Banglore
# 10589    Air India      27/04/2019   Kolkata    Banglore
# 10590  Jet Airways      27/04/2019  Banglore       Delhi
# 10591      Vistara      01/03/2019  Banglore   New Delhi
# 10592    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 1      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 2            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 3            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# 4                  CCU → BLR    09:00         11:25   2h 25m    non-stop
# ...                      ...      ...           ...      ...         ...
# 10588              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10589              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10590              BLR → DEL    08:20         11:20       3h    non-stop
# 10591              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10592  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price  DayOfJourney  MonthOfJourney  \
# 0             No info   7662             1               5
# 1             No info  13882             9               6
# 2             No info   6218            12               5
# 3             No info  13302             1               3
# 4             No info   3873            24               6
# ...               ...    ...           ...             ...
# 10588         No info   4107             9               4
# 10589         No info   4145            27               4
# 10590         No info   7229            27               4
# 10591         No info  12648             1               3
# 10592         No info  11753             9               5
#
#       AccurateArrivalTime AccurateArrivalDay AccurateArrivalMonth  \
# 0                   13:15               None                 None
# 1                   04:25                 10                  Jun
# 2                   23:30               None                 None
# 3                   21:35               None                 None
# 4                   11:25               None                 None
# ...                   ...                ...                  ...
# 10588               22:25               None                 None
# 10589               23:20               None                 None
# 10590               11:20               None                 None
# 10591               14:10               None                 None
# 10592               19:15               None                 None
#
#        DayDifference
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# 10588          False
# 10589          False
# 10590          False
# 10591          False
# 10592          False
#
# [10593 rows x 17 columns]

# %%
PartOfData = data[data['AccurateArrivalDay']!='None']
PartOfData
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 1      Jet Airways       9/06/2019     Delhi      Cochin
# 5      Jet Airways      12/03/2019  Banglore   New Delhi
# 6      Jet Airways      01/03/2019  Banglore   New Delhi
# 7      Jet Airways      12/03/2019  Banglore   New Delhi
# 12     Jet Airways       9/05/2019   Kolkata    Banglore
# ...            ...             ...       ...         ...
# 10576  Jet Airways      12/06/2019     Delhi      Cochin
# 10577  Jet Airways      12/03/2019  Banglore   New Delhi
# 10582  Jet Airways      27/06/2019     Delhi      Cochin
# 10583  Jet Airways      27/05/2019     Delhi      Cochin
# 10584  Jet Airways      12/03/2019  Banglore   New Delhi
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 1      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 5            BLR → BOM → DEL    18:55  10:25 13 Mar  15h 30m      1 stop
# 6            BLR → BOM → DEL    08:00  05:05 02 Mar   21h 5m      1 stop
# 7            BLR → BOM → DEL    08:55  10:25 13 Mar  25h 30m      1 stop
# 12           CCU → BOM → BLR    21:10  09:20 10 May  12h 10m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10576        DEL → BOM → COK    18:15  19:00 13 Jun  24h 45m      1 stop
# 10577        BLR → BOM → DEL    22:55  20:20 13 Mar  21h 25m      1 stop
# 10582  DEL → AMD → BOM → COK    23:05  19:00 28 Jun  19h 55m     2 stops
# 10583  DEL → AMD → BOM → COK    13:25  04:25 28 May      15h     2 stops
# 10584        BLR → BOM → DEL    20:35  21:20 13 Mar  24h 45m      1 stop
#
#                    Additional_Info  Price  DayOfJourney  MonthOfJourney  \
# 1                          No info  13882             9               6
# 5      In-flight meal not included  11087            12               3
# 6                          No info  22270             1               3
# 7      In-flight meal not included  11087            12               3
# 12     In-flight meal not included   9663             9               5
# ...                            ...    ...           ...             ...
# 10576  In-flight meal not included  10262            12               6
# 10577  In-flight meal not included  11087            12               3
# 10582  In-flight meal not included  11150            27               6
# 10583                      No info  16704            27               5
# 10584  In-flight meal not included  11087            12               3
#
#       AccurateArrivalTime AccurateArrivalDay AccurateArrivalMonth  \
# 1                   04:25                 10                  Jun
# 5                   10:25                 13                  Mar
# 6                   05:05                 02                  Mar
# 7                   10:25                 13                  Mar
# 12                  09:20                 10                  May
# ...                   ...                ...                  ...
# 10576               19:00                 13                  Jun
# 10577               20:20                 13                  Mar
# 10582               19:00                 28                  Jun
# 10583               04:25                 28                  May
# 10584               21:20                 13                  Mar
#
#        DayDifference
# 1              False
# 5              False
# 6              False
# 7              False
# 12             False
# ...              ...
# 10576          False
# 10577          False
# 10582          False
# 10583          False
# 10584          False
#
# [4245 rows x 17 columns]

# %%
Differences = []
for a,b in zip(PartOfData['DayOfJourney'].tolist(),PartOfData['AccurateArrivalDay'].tolist()) : 
    Differences.append(int(b) - int(a))
set(Differences)

# PartOfData['DayOfJourney'] = PartOfData['DayOfJourney'].astype(int)
# PartOfData['AccurateArrivalDay'] = PartOfData['AccurateArrivalDay'].astype(int)
# PartOfData[['DayOfJourney','AccurateArrivalDay']]
# Out:
# {1, 2, 4}

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 1  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 2       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 3       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
# 4     SpiceJet      24/06/2019   Kolkata    Banglore              CCU → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    05:50         13:15   7h 25m     2 stops         No info   7662
# 1    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 2    18:05         23:30   5h 25m      1 stop         No info   6218
# 3    16:50         21:35   4h 45m      1 stop         No info  13302
# 4    09:00         11:25   2h 25m    non-stop         No info   3873
#
#    DayOfJourney  MonthOfJourney AccurateArrivalTime AccurateArrivalDay  \
# 0             1               5               13:15               None
# 1             9               6               04:25                 10
# 2            12               5               23:30               None
# 3             1               3               21:35               None
# 4            24               6               11:25               None
#
#   AccurateArrivalMonth  DayDifference
# 0                 None          False
# 1                  Jun          False
# 2                 None          False
# 3                 None          False
# 4                 None          False

# %%
def GetDiff(ArrivalDay,DepDay) : 
    if ArrivalDay != 'None' : 
        if int(ArrivalDay) - int(DepDay) == 4 : 
            return True
        else :
            return False
    else : 
        return False
    
data['Big Diff'] = data.apply(lambda x : GetDiff(x.AccurateArrivalDay,x.DayOfJourney),axis=1)

# %%
data['Big Diff'].value_counts()
# Out:
# False    10541
# True        52
# Name: Big Diff, dtype: int64

# %%
data.drop(data[data['Big Diff']==True].index,axis=0,inplace=True)
data.reset_index(inplace=True)
data.drop(['index'],axis=1,inplace=True)

# %%
data['Big Diff'].value_counts()
# Out:
# False    10541
# Name: Big Diff, dtype: int64

# %%
pd.Series([len(i.split()) for i in data['Duration'].tolist()]).value_counts()
# Out:
# 2    9522
# 1    1019
# dtype: int64

# %%
BothHM,HAlone,MAlone,NoHM =0,0,0,0
for i in data['Duration'].tolist() : 
    if 'h' in i and 'm' in i : 
        BothHM+= 1 
    elif 'h' in i and not 'm' in i : 
        HAlone+=1
    elif not 'h' in i and  'm' in i : 
        MAlone+=1
    else : 
        NoHM  +=1
        
BothHM,HAlone,MAlone,NoHM
# Out:
# (9522, 1018, 1, 0)

# %%
for n,i in enumerate(data['Duration'].tolist()) : 
    if not 'h' in i and  'm' in i  : 
        print(n)
# Out:
# 6389

# %%
data.loc[6389,:]
# Out:
# Airline                             Air India
# Date_of_Journey                     6/03/2019
# Source                                 Mumbai
# Destination                         Hyderabad
# Route                   BOM → GOI → PNQ → HYD
# Dep_Time                                16:50
# Arrival_Time                            16:55
# Duration                                   5m
# Total_Stops                           2 stops
# Additional_Info                       No info
# Price                                   17327
# DayOfJourney                                6
# MonthOfJourney                              3
# AccurateArrivalTime                     16:55
# AccurateArrivalDay                       None
# AccurateArrivalMonth                     None
# DayDifference                           False
# Big Diff                                False
# Name: 6389, dtype: object

# %%
data.drop([6389],axis = 0 , inplace=True)
data.reset_index(inplace=True)
data.drop(['index'],axis=1,inplace=True)

# %%
BothHM,HAlone,MAlone,NoHM =0,0,0,0
for i in data['Duration'].tolist() : 
    if 'h' in i and 'm' in i : 
        BothHM+= 1 
    elif 'h' in i and not 'm' in i : 
        HAlone+=1
    elif not 'h' in i and  'm' in i : 
        MAlone+=1
    else : 
        NoHM  +=1
        
BothHM,HAlone,MAlone,NoHM
# Out:
# (9522, 1018, 0, 0)

# %%
#7h 25m	

def DurationTime(n) : 
    if 'm' in n : 
        H = n.split()[0]
        H = H.strip('h')
        
        M = n.split()[1]
        M = M.strip('m')
        return (int(H)*60) + int(M)
    else : 
        H = n.strip('h')
        return int(H)*60
        
data['DurationInMinutes']     = data['Duration'].apply(lambda x : DurationTime(x))

#df_train['Duration'] = df_train['Duration'].str.replace('h','*60').str.replace(' ','+').str.replace('m','*1').apply(eval)

# %%
data[['Duration','DurationInMinutes']]
# Out:
#       Duration  DurationInMinutes
# 0       7h 25m                445
# 1          19h               1140
# 2       5h 25m                325
# 3       4h 45m                285
# 4       2h 25m                145
# ...        ...                ...
# 10535   2h 30m                150
# 10536   2h 35m                155
# 10537       3h                180
# 10538   2h 40m                160
# 10539   8h 20m                500
#
# [10540 rows x 2 columns]

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 1  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 2       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 3       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
# 4     SpiceJet      24/06/2019   Kolkata    Banglore              CCU → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    05:50         13:15   7h 25m     2 stops         No info   7662
# 1    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 2    18:05         23:30   5h 25m      1 stop         No info   6218
# 3    16:50         21:35   4h 45m      1 stop         No info  13302
# 4    09:00         11:25   2h 25m    non-stop         No info   3873
#
#    DayOfJourney  MonthOfJourney AccurateArrivalTime AccurateArrivalDay  \
# 0             1               5               13:15               None
# 1             9               6               04:25                 10
# 2            12               5               23:30               None
# 3             1               3               21:35               None
# 4            24               6               11:25               None
#
#   AccurateArrivalMonth  DayDifference  Big Diff  DurationInMinutes
# 0                 None          False     False                445
# 1                  Jun          False     False               1140
# 2                 None          False     False                325
# 3                 None          False     False                285
# 4                 None          False     False                145

# %%
data['StopsCount'] = data['Route'].apply(lambda x : str(x).count('→') -1)

data[['Total_Stops','StopsCount']]
# Out:
#       Total_Stops  StopsCount
# 0         2 stops           2
# 1         2 stops           2
# 2          1 stop           1
# 3          1 stop           1
# 4        non-stop           0
# ...           ...         ...
# 10535    non-stop           0
# 10536    non-stop           0
# 10537    non-stop           0
# 10538    non-stop           0
# 10539     2 stops           2
#
# [10540 rows x 2 columns]

# %%
data['Total_Stops'].value_counts()
# Out:
# 1 stop      5527
# non-stop    3470
# 2 stops     1498
# 3 stops       44
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %%
data['StopsCount'].value_counts()
# Out:
# 1    5527
# 0    3470
# 2    1498
# 3      44
# 4       1
# Name: StopsCount, dtype: int64

# %%
StopDict = {0:'non-stop',1:'1 stop',2:'2 stops',3:'3 stops',4:'4 stops'}

# %%
for a,b in zip(data['StopsCount'].tolist(),data['Total_Stops'].tolist()) : 
    if StopDict[a] != b : 
        print(a)

# %%
data[data['StopsCount']==4]
# Out:
#         Airline Date_of_Journey    Source Destination  \
# 9064  Air India      01/03/2019  Banglore   New Delhi
#
#                                   Route Dep_Time  Arrival_Time Duration  \
# 9064  BLR → CCU → BBI → HYD → VGA → DEL    05:50  11:20 02 Mar  29h 30m
#
#      Total_Stops  Additional_Info  Price  DayOfJourney  MonthOfJourney  \
# 9064     4 stops  Change airports  17686             1               3
#
#      AccurateArrivalTime AccurateArrivalDay AccurateArrivalMonth  \
# 9064               11:20                 02                  Mar
#
#       DayDifference  Big Diff  DurationInMinutes  StopsCount
# 9064          False     False               1770           4

# %%
data['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
data['Additional_Info'].value_counts()
# Out:
# No info                         8254
# In-flight meal not included     1930
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64

# %%
data['MealIncluded'] = data['Additional_Info'].apply(lambda x : 1 if x != 'In-flight meal not included' else 0)
data['MealIncluded'].value_counts()
# Out:
# 1    8610
# 0    1930
# Name: MealIncluded, dtype: int64

# %%
data['Additional_Info'].replace('No Info','No info',inplace = True)

# %%
data['Additional_Info'].value_counts()
# Out:
# No info                         8257
# In-flight meal not included     1930
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 1  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 2       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 3       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
# 4     SpiceJet      24/06/2019   Kolkata    Banglore              CCU → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  ...  \
# 0    05:50         13:15   7h 25m     2 stops         No info  ...
# 1    09:25  04:25 10 Jun      19h     2 stops         No info  ...
# 2    18:05         23:30   5h 25m      1 stop         No info  ...
# 3    16:50         21:35   4h 45m      1 stop         No info  ...
# 4    09:00         11:25   2h 25m    non-stop         No info  ...
#
#    DayOfJourney  MonthOfJourney  AccurateArrivalTime AccurateArrivalDay  \
# 0             1               5                13:15               None
# 1             9               6                04:25                 10
# 2            12               5                23:30               None
# 3             1               3                21:35               None
# 4            24               6                11:25               None
#
#   AccurateArrivalMonth DayDifference  Big Diff  DurationInMinutes  StopsCount  \
# 0                 None         False     False                445           2
# 1                  Jun         False     False               1140           2
# 2                 None         False     False                325           1
# 3                 None         False     False                285           1
# 4                 None         False     False                145           0
#
#    MealIncluded
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
#
# [5 rows x 21 columns]

# %%
def DayPart(n) : 
    H = int(n.split(':')[0])
    if H < 6 : 
        return 'Early Morning'
    elif 6<=H < 12 : 
        return 'Morning'
    elif  12<=H < 15 : 
        return 'Noon'
    elif  15<=H < 19 : 
        return 'Evening'
    else : 
        return 'Night'
    
data['DepartureDayPart']   = data['Dep_Time'].apply(lambda x : DayPart(x))
data['ArrivalDayPart']   = data['AccurateArrivalTime'].apply(lambda x : DayPart(x))
data[['Dep_Time','DepartureDayPart','AccurateArrivalTime','ArrivalDayPart']]
# Out:
#       Dep_Time DepartureDayPart AccurateArrivalTime ArrivalDayPart
# 0        05:50    Early Morning               13:15           Noon
# 1        09:25          Morning               04:25  Early Morning
# 2        18:05          Evening               23:30          Night
# 3        16:50          Evening               21:35          Night
# 4        09:00          Morning               11:25        Morning
# ...        ...              ...                 ...            ...
# 10535    19:55            Night               22:25          Night
# 10536    20:45            Night               23:20          Night
# 10537    08:20          Morning               11:20        Morning
# 10538    11:30          Morning               14:10           Noon
# 10539    10:55          Morning               19:15          Night
#
# [10540 rows x 4 columns]

# %%
data.corr()
# Out:
#                       Price  DayOfJourney  MonthOfJourney  DayDifference  \
# Price              1.000000     -0.155767       -0.099739            NaN
# DayOfJourney      -0.155767      1.000000       -0.035612            NaN
# MonthOfJourney    -0.099739     -0.035612        1.000000            NaN
# DayDifference           NaN           NaN             NaN            NaN
# Big Diff                NaN           NaN             NaN            NaN
# DurationInMinutes  0.517399     -0.022593        0.029929            NaN
# StopsCount         0.610535     -0.008186        0.061468            NaN
# MealIncluded      -0.041719     -0.033078       -0.087114            NaN
#
#                    Big Diff  DurationInMinutes  StopsCount  MealIncluded
# Price                   NaN           0.517399    0.610535     -0.041719
# DayOfJourney            NaN          -0.022593   -0.008186     -0.033078
# MonthOfJourney          NaN           0.029929    0.061468     -0.087114
# DayDifference           NaN                NaN         NaN           NaN
# Big Diff                NaN                NaN         NaN           NaN
# DurationInMinutes       NaN           1.000000    0.739098     -0.189614
# StopsCount              NaN           0.739098    1.000000     -0.106112
# MealIncluded            NaN          -0.189614   -0.106112      1.000000

# %%
data['DurationInMinutes'].min(),data['DurationInMinutes'].max()
# Out:
# (75, 2860)

# %%
def FlightLength(H) : 
    if H < 180 : 
        return 'Short'
    elif 180<=H < 600 : 
        return 'Medium'
    else : 
        return 'Long'
    
data['FlightLength']   = data['DurationInMinutes'].apply(lambda x : FlightLength(x))
data[['DurationInMinutes','FlightLength']]
# Out:
#        DurationInMinutes FlightLength
# 0                    445       Medium
# 1                   1140         Long
# 2                    325       Medium
# 3                    285       Medium
# 4                    145        Short
# ...                  ...          ...
# 10535                150        Short
# 10536                155        Short
# 10537                180       Medium
# 10538                160        Short
# 10539                500       Medium
#
# [10540 rows x 2 columns]

# %%
data['FlightLength'].value_counts()
# Out:
# Long      4651
# Short     3002
# Medium    2887
# Name: FlightLength, dtype: int64

# %%
data['Price'].min(),data['Price'].max()
# Out:
# (1759, 79512)

# %%
def PriceRange(H) : 
    if H < 5000 : 
        return 'Cheap'
    elif 5000<=H < 10000 : 
        return 'Medium'
    else : 
        return 'Expensive'
    
data['PriceRange']   = data['Price'].apply(lambda x : PriceRange(x))
data[['Price','PriceRange']]
# Out:
#        Price PriceRange
# 0       7662     Medium
# 1      13882  Expensive
# 2       6218     Medium
# 3      13302  Expensive
# 4       3873      Cheap
# ...      ...        ...
# 10535   4107      Cheap
# 10536   4145      Cheap
# 10537   7229     Medium
# 10538  12648  Expensive
# 10539  11753  Expensive
#
# [10540 rows x 2 columns]

# %%
data['PriceRange'].value_counts()
# Out:
# Expensive    4293
# Medium       3871
# Cheap        2376
# Name: PriceRange, dtype: int64

# %%
data['Source'].unique()
# Out:
# array(['Kolkata', 'Delhi', 'Banglore', 'Chennai', 'Mumbai'], dtype=object)

# %%
# s=['Delhi','Kolkata','Banglore','Mumbai','Chennai']
# for x in s:
#     geolocator = Nominatim(user_agent="Singularity")
#     location=geolocator.geocode(x)
#     print(f'country:{x}')
#     print((location.latitude,location.longitude))
#     print('-'*20)


# df['Source'].replace('Delhi','28.6517178,77.2219388',inplace=True)
# df['Source'].replace('Kolkata','22.5414185,88.35769124388872',inplace=True)
# df['Source'].replace('Banglore','12.9587464,77.5573456',inplace=True)
# df['Source'].replace('Mumbai','19.0759899,72.8773928',inplace=True)
# df['Source'].replace('Chennai','13.0836939,80.270186',inplace=True)


# d=['Cochin','Banglore','Delhi','New Delhi','Hyderabad','Kolkata' ]
# for i in d:
#     geolocator = Nominatim(user_agent="Singularity")
#     location=geolocator.geocode(i)
#     print(f'country:{i}')
#     print((location.latitude,location.longitude))
#     print('-'*20)

# df['Destination'].replace('Cochin','9.931308,76.2674136',inplace=True)
# df['Destination'].replace('Banglore','12.9587464,77.5573456',inplace=True)
# df['Destination'].replace('Delhi','28.6517178,77.2219388',inplace=True)
# df['Destination'].replace('New Delhi','28.6138954,77.2090057',inplace=True)
# df['Destination'].replace('Hyderabad','17.360589,78.4740613',inplace=True)
# df['Destination'].replace('Kolkata','22.5414185,88.35769124388872',inplace=True)
# df



# df['source_lat']=df['Source'].apply(lambda x: x.split(',')[0])
# df['source_lon']=df['Source'].apply(lambda x: x.split(',')[1])
# df['destination_lat']=df['Destination'].apply(lambda x: x.split(',')[0])
# df['destination_lon']=df['Destination'].apply(lambda x: x.split(',')[1])
# df.drop(['Source','Destination'],axis=1,inplace=True)


# df['distance']=haversine_distance(df['source_lat'],df['source_lon'],df['destination_lat'],df['destination_lon'])

# %% [markdown]
# # 5) Data Visualization

# %%
def CPlot(feature) : 
    global data
    fig,ax = plt.subplots(figsize = (10,6))
    sns.countplot(x = feature,data=data,facecolor = (0,0,0,0),linewidth = 5,
                  edgecolor= sns.color_palette('dark',3))
    ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
    return None

def KPlot(feature) : 
    global data
    fig,ax = plt.subplots(figsize = (10,6))
    sns.kdeplot(data[feature],shade=True)
    return None

def Pie(feature,limit=20) : 
    global data
    fig,ax = plt.subplots(figsize = (10,6))
    plt.pie(data[feature].value_counts()[:limit],labels = list(data[feature].value_counts()[:limit].index),
            autopct = '%1.2f%%',labeldistance= 1.1)
    return None

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 1  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 2       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 3       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
# 4     SpiceJet      24/06/2019   Kolkata    Banglore              CCU → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  ...  \
# 0    05:50         13:15   7h 25m     2 stops         No info  ...
# 1    09:25  04:25 10 Jun      19h     2 stops         No info  ...
# 2    18:05         23:30   5h 25m      1 stop         No info  ...
# 3    16:50         21:35   4h 45m      1 stop         No info  ...
# 4    09:00         11:25   2h 25m    non-stop         No info  ...
#
#    AccurateArrivalMonth  DayDifference  Big Diff DurationInMinutes StopsCount  \
# 0                  None          False     False               445          2
# 1                   Jun          False     False              1140          2
# 2                  None          False     False               325          1
# 3                  None          False     False               285          1
# 4                  None          False     False               145          0
#
#   MealIncluded  DepartureDayPart  ArrivalDayPart  FlightLength  PriceRange
# 0            1     Early Morning            Noon        Medium      Medium
# 1            1           Morning   Early Morning          Long   Expensive
# 2            1           Evening           Night        Medium      Medium
# 3            1           Evening           Night        Medium   Expensive
# 4            1           Morning         Morning         Short       Cheap
#
# [5 rows x 25 columns]

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price', 'DayOfJourney', 'MonthOfJourney',
#        'AccurateArrivalTime', 'AccurateArrivalDay', 'AccurateArrivalMonth',
#        'DayDifference', 'Big Diff', 'DurationInMinutes', 'StopsCount',
#        'MealIncluded', 'DepartureDayPart', 'ArrivalDayPart', 'FlightLength',
#        'PriceRange'],
#       dtype='object')

# %%
len(data['Airline'].unique())
# Out:
# 12

# %%
Pie('Airline',8)

# %%
CPlot('Airline')

# %%
CPlot('Source')

# %%
CPlot('Destination')

# %%
Pie('Route',10)

# %%
Pie('Dep_Time',10)

# %%
Pie('DepartureDayPart')

# %%
Pie('AccurateArrivalTime',15)

# %%
Pie('ArrivalDayPart')

# %%
# CPlot('DurationInMinutes')

# %%
KPlot('DurationInMinutes')

# %%
CPlot('Total_Stops')

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price', 'DayOfJourney', 'MonthOfJourney',
#        'AccurateArrivalTime', 'AccurateArrivalDay', 'AccurateArrivalMonth',
#        'DayDifference', 'Big Diff', 'DurationInMinutes', 'StopsCount',
#        'MealIncluded', 'DepartureDayPart', 'ArrivalDayPart', 'FlightLength',
#        'PriceRange'],
#       dtype='object')

# %%
CPlot('Additional_Info')

# %%
Pie('Additional_Info')

# %%
Data = data[data['Additional_Info']!='No info']
Data.shape
# Out:
# (2283, 25)

# %%
feature = 'Additional_Info'
limit = 10
fig,ax = plt.subplots(figsize = (10,6))
plt.pie(Data[feature].value_counts()[:limit],labels = list(Data[feature].value_counts()[:limit].index),
        autopct = '%1.2f%%',labeldistance= 1.1)
# Out:
# ([<matplotlib.patches.Wedge at 0x230a89a7cd0>,
#   <matplotlib.patches.Wedge at 0x230a89ae460>,
#   <matplotlib.patches.Wedge at 0x230a89aeb80>,
#   <matplotlib.patches.Wedge at 0x230a8c322e0>,
#   <matplotlib.patches.Wedge at 0x230a8c32a00>,
#   <matplotlib.patches.Wedge at 0x230a8c5c160>,
#   <matplotlib.patches.Wedge at 0x230a8c5c880>,
#   <matplotlib.patches.Wedge at 0x230a8c5cfa0>],
#  [Text(-0.9727541650697858, 0.5135653165269087, 'In-flight meal not included'),
#   Text(0.9484380125978066, -0.5571941638778382, 'No check-in baggage included'),
#   Text(1.0977001686176222, -0.07109388030515887, '1 Long layover'),
#   Text(1.099540737169727, -0.031783129239478985, 'Change airports'),
#   Text(1.099895852559876, -0.01513649634437996, 'Business class'),
#   Text(1.0999739625425609, -0.00756846935763511, '1 Short layover'),
#   Text(1.0999906263528105, -0.00454113817802701, 'Red-eye flight'),
#   Text(1.099998958405193, -0.0015137726020688328, '2 Long layover')],
#  [Text(-0.5305931809471558, 0.28012653628740475, '84.54%'),
#   Text(0.517329825053349, -0.30392408938791166, '14.02%'),
#   Text(0.5987455465187029, -0.03877848016645029, '0.83%'),
#   Text(0.5997494930016692, -0.01733625231244308, '0.31%'),
#   Text(0.5999431923053868, -0.008256270733298158, '0.18%'),
#   Text(0.5999857977504877, -0.004128256013255514, '0.04%'),
#   Text(0.5999948871015329, -0.002476984460742005, '0.04%'),
#   Text(0.5999994318573779, -0.0008256941465829996, '0.04%')])

# %%
KPlot('Price')

# %%
Pie('PriceRange')

# %%
CPlot('StopsCount')

# %%
Pie('MealIncluded')

# %%
CPlot('FlightLength')

# %%
data['PriceRange'].unique()
# Out:
# array(['Medium', 'Expensive', 'Cheap'], dtype=object)

# %%
def SelectedFeaturePie(feature,limit=10) : 
    global data
    fig,ax = plt.subplots(figsize = (15,5))
    
    plt.subplot(1,3,1)
    plt.title('Cheap Tickets')
    Data = data[data['PriceRange']=='Cheap']
    plt.pie(Data[feature].value_counts()[:limit],labels = list(Data[feature].value_counts()[:limit].index),
            autopct = '%1.2f%%',labeldistance= 1.1)

    plt.subplot(1,3,2)
    plt.title('Medium Tickets')
    Data = data[data['PriceRange']=='Medium']
    plt.pie(Data[feature].value_counts()[:limit],labels = list(Data[feature].value_counts()[:limit].index),
            autopct = '%1.2f%%',labeldistance= 1.1)

    plt.subplot(1,3,3)
    plt.title('Expensive Tickets')
    Data = data[data['PriceRange']=='Expensive']
    plt.pie(Data[feature].value_counts()[:limit],labels = list(Data[feature].value_counts()[:limit].index),
            autopct = '%1.2f%%',labeldistance= 1.1)
    
    return None

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price', 'DayOfJourney', 'MonthOfJourney',
#        'AccurateArrivalTime', 'AccurateArrivalDay', 'AccurateArrivalMonth',
#        'DayDifference', 'Big Diff', 'DurationInMinutes', 'StopsCount',
#        'MealIncluded', 'DepartureDayPart', 'ArrivalDayPart', 'FlightLength',
#        'PriceRange'],
#       dtype='object')

# %%
SelectedFeaturePie('Airline',5)

# %%
SelectedFeaturePie('Source',5)

# %%
SelectedFeaturePie('Destination',5)

# %%
SelectedFeaturePie('PriceRange',5)

# %% [markdown]
# # 6) Data Preparing

# %%
pd.set_option('display.max_columns',None)
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 1  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 2       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 3       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
# 4     SpiceJet      24/06/2019   Kolkata    Banglore              CCU → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    05:50         13:15   7h 25m     2 stops         No info   7662
# 1    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 2    18:05         23:30   5h 25m      1 stop         No info   6218
# 3    16:50         21:35   4h 45m      1 stop         No info  13302
# 4    09:00         11:25   2h 25m    non-stop         No info   3873
#
#    DayOfJourney  MonthOfJourney AccurateArrivalTime AccurateArrivalDay  \
# 0             1               5               13:15               None
# 1             9               6               04:25                 10
# 2            12               5               23:30               None
# 3             1               3               21:35               None
# 4            24               6               11:25               None
#
#   AccurateArrivalMonth  DayDifference  Big Diff  DurationInMinutes  \
# 0                 None          False     False                445
# 1                  Jun          False     False               1140
# 2                 None          False     False                325
# 3                 None          False     False                285
# 4                 None          False     False                145
#
#    StopsCount  MealIncluded DepartureDayPart ArrivalDayPart FlightLength  \
# 0           2             1    Early Morning           Noon       Medium
# 1           2             1          Morning  Early Morning         Long
# 2           1             1          Evening          Night       Medium
# 3           1             1          Evening          Night       Medium
# 4           0             1          Morning        Morning        Short
#
#   PriceRange
# 0     Medium
# 1  Expensive
# 2     Medium
# 3  Expensive
# 4      Cheap

# %%
data['DepartureHour'] = data['Dep_Time'].apply(lambda x : x.split(':')[0])
data['ArrivalHour'] = data['AccurateArrivalTime'].apply(lambda x : x.split(':')[0])

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 1  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 2       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 3       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
# 4     SpiceJet      24/06/2019   Kolkata    Banglore              CCU → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    05:50         13:15   7h 25m     2 stops         No info   7662
# 1    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 2    18:05         23:30   5h 25m      1 stop         No info   6218
# 3    16:50         21:35   4h 45m      1 stop         No info  13302
# 4    09:00         11:25   2h 25m    non-stop         No info   3873
#
#    DayOfJourney  MonthOfJourney AccurateArrivalTime AccurateArrivalDay  \
# 0             1               5               13:15               None
# 1             9               6               04:25                 10
# 2            12               5               23:30               None
# 3             1               3               21:35               None
# 4            24               6               11:25               None
#
#   AccurateArrivalMonth  DayDifference  Big Diff  DurationInMinutes  \
# 0                 None          False     False                445
# 1                  Jun          False     False               1140
# 2                 None          False     False                325
# 3                 None          False     False                285
# 4                 None          False     False                145
#
#    StopsCount  MealIncluded DepartureDayPart ArrivalDayPart FlightLength  \
# 0           2             1    Early Morning           Noon       Medium
# 1           2             1          Morning  Early Morning         Long
# 2           1             1          Evening          Night       Medium
# 3           1             1          Evening          Night       Medium
# 4           0             1          Morning        Morning        Short
#
#   PriceRange DepartureHour ArrivalHour
# 0     Medium            05          13
# 1  Expensive            09          04
# 2     Medium            18          23
# 3  Expensive            16          21
# 4      Cheap            09          11

# %%
from sklearn.preprocessing import LabelEncoder

# %%
AirLineEnc,SourceEnc,DestinationEnc,AdditionalInfoEnc,MealIncludedEnc,DepDayEnc,ArrivDayEnc,FlightLengthEnc = LabelEncoder(),LabelEncoder(),LabelEncoder(),LabelEncoder(),LabelEncoder(),LabelEncoder(),LabelEncoder(),LabelEncoder()

# %%
def ApplyEncoder(Encoder,OriginalColumn) : 
    global data
    Encoder.fit(data[OriginalColumn])
    return Encoder.transform(data[OriginalColumn])

# %%
data['AirLineEnc'] = ApplyEncoder(AirLineEnc,'Airline')
data['SourceEnc'] = ApplyEncoder(SourceEnc,'Source')
data['DestinationEnc'] = ApplyEncoder(DestinationEnc,'Destination')
data['AdditionalInfoEnc'] = ApplyEncoder(AdditionalInfoEnc,'Additional_Info')
data['MealIncludedEnc'] = ApplyEncoder(MealIncludedEnc,'MealIncluded')
data['DepDayEnc'] = ApplyEncoder(DepDayEnc,'DepartureDayPart')
data['ArrivDayEnc'] = ApplyEncoder(ArrivDayEnc,'ArrivalDayPart')
data['FlightLengthEnc'] = ApplyEncoder(FlightLengthEnc,'FlightLength')
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 1  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 2       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 3       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
# 4     SpiceJet      24/06/2019   Kolkata    Banglore              CCU → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    05:50         13:15   7h 25m     2 stops         No info   7662
# 1    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 2    18:05         23:30   5h 25m      1 stop         No info   6218
# 3    16:50         21:35   4h 45m      1 stop         No info  13302
# 4    09:00         11:25   2h 25m    non-stop         No info   3873
#
#    DayOfJourney  MonthOfJourney AccurateArrivalTime AccurateArrivalDay  \
# 0             1               5               13:15               None
# 1             9               6               04:25                 10
# 2            12               5               23:30               None
# 3             1               3               21:35               None
# 4            24               6               11:25               None
#
#   AccurateArrivalMonth  DayDifference  Big Diff  DurationInMinutes  \
# 0                 None          False     False                445
# 1                  Jun          False     False               1140
# 2                 None          False     False                325
# 3                 None          False     False                285
# 4                 None          False     False                145
#
#    StopsCount  MealIncluded DepartureDayPart ArrivalDayPart FlightLength  \
# 0           2             1    Early Morning           Noon       Medium
# 1           2             1          Morning  Early Morning         Long
# 2           1             1          Evening          Night       Medium
# 3           1             1          Evening          Night       Medium
# 4           0             1          Morning        Morning        Short
#
#   PriceRange DepartureHour ArrivalHour  AirLineEnc  SourceEnc  DestinationEnc  \
# 0     Medium            05          13           1          3               0
# 1  Expensive            09          04           4          2               1
# 2     Medium            18          23           3          3               0
# 3  Expensive            16          21           3          0               5
# 4      Cheap            09          11           8          3               0
#
#    AdditionalInfoEnc  MealIncludedEnc  DepDayEnc  ArrivDayEnc  FlightLengthEnc
# 0                  7                1          0            4                1
# 1                  7                1          2            0                0
# 2                  7                1          1            3                1
# 3                  7                1          1            3                1
# 4                  7                1          2            2                2

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price', 'DayOfJourney', 'MonthOfJourney',
#        'AccurateArrivalTime', 'AccurateArrivalDay', 'AccurateArrivalMonth',
#        'DayDifference', 'Big Diff', 'DurationInMinutes', 'StopsCount',
#        'MealIncluded', 'DepartureDayPart', 'ArrivalDayPart', 'FlightLength',
#        'PriceRange', 'DepartureHour', 'ArrivalHour', 'AirLineEnc', 'SourceEnc',
#        'DestinationEnc', 'AdditionalInfoEnc', 'MealIncludedEnc', 'DepDayEnc',
#        'ArrivDayEnc', 'FlightLengthEnc'],
#       dtype='object')

# %%
ColumnsToInt = ['DayOfJourney','MonthOfJourney','DurationInMinutes','StopsCount','DepartureHour','ArrivalHour']

for col in ColumnsToInt : 
    data[col] = data[col].astype(int)
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 1  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 2       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 3       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
# 4     SpiceJet      24/06/2019   Kolkata    Banglore              CCU → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    05:50         13:15   7h 25m     2 stops         No info   7662
# 1    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 2    18:05         23:30   5h 25m      1 stop         No info   6218
# 3    16:50         21:35   4h 45m      1 stop         No info  13302
# 4    09:00         11:25   2h 25m    non-stop         No info   3873
#
#    DayOfJourney  MonthOfJourney AccurateArrivalTime AccurateArrivalDay  \
# 0             1               5               13:15               None
# 1             9               6               04:25                 10
# 2            12               5               23:30               None
# 3             1               3               21:35               None
# 4            24               6               11:25               None
#
#   AccurateArrivalMonth  DayDifference  Big Diff  DurationInMinutes  \
# 0                 None          False     False                445
# 1                  Jun          False     False               1140
# 2                 None          False     False                325
# 3                 None          False     False                285
# 4                 None          False     False                145
#
#    StopsCount  MealIncluded DepartureDayPart ArrivalDayPart FlightLength  \
# 0           2             1    Early Morning           Noon       Medium
# 1           2             1          Morning  Early Morning         Long
# 2           1             1          Evening          Night       Medium
# 3           1             1          Evening          Night       Medium
# 4           0             1          Morning        Morning        Short
#
#   PriceRange  DepartureHour  ArrivalHour  AirLineEnc  SourceEnc  \
# 0     Medium              5           13           1          3
# 1  Expensive              9            4           4          2
# 2     Medium             18           23           3          3
# 3  Expensive             16           21           3          0
# 4      Cheap              9           11           8          3
#
#    DestinationEnc  AdditionalInfoEnc  MealIncludedEnc  DepDayEnc  ArrivDayEnc  \
# 0               0                  7                1          0            4
# 1               1                  7                1          2            0
# 2               0                  7                1          1            3
# 3               5                  7                1          1            3
# 4               0                  7                1          2            2
#
#    FlightLengthEnc
# 0                1
# 1                0
# 2                1
# 3                1
# 4                2

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price', 'DayOfJourney', 'MonthOfJourney',
#        'AccurateArrivalTime', 'AccurateArrivalDay', 'AccurateArrivalMonth',
#        'DayDifference', 'Big Diff', 'DurationInMinutes', 'StopsCount',
#        'MealIncluded', 'DepartureDayPart', 'ArrivalDayPart', 'FlightLength',
#        'PriceRange', 'DepartureHour', 'ArrivalHour', 'AirLineEnc', 'SourceEnc',
#        'DestinationEnc', 'AdditionalInfoEnc', 'MealIncludedEnc', 'DepDayEnc',
#        'ArrivDayEnc', 'FlightLengthEnc'],
#       dtype='object')

# %%
X = data[['DayOfJourney', 'MonthOfJourney','DurationInMinutes', 'StopsCount',
        'DepartureHour', 'ArrivalHour', 'AirLineEnc', 'SourceEnc',
       'DestinationEnc', 'AdditionalInfoEnc', 'MealIncludedEnc', 'DepDayEnc',
       'ArrivDayEnc', 'FlightLengthEnc']]

y = data['Price']

# %%
X
# Out:
#        DayOfJourney  MonthOfJourney  DurationInMinutes  StopsCount  \
# 0                 1               5                445           2
# 1                 9               6               1140           2
# 2                12               5                325           1
# 3                 1               3                285           1
# 4                24               6                145           0
# ...             ...             ...                ...         ...
# 10535             9               4                150           0
# 10536            27               4                155           0
# 10537            27               4                180           0
# 10538             1               3                160           0
# 10539             9               5                500           2
#
#        DepartureHour  ArrivalHour  AirLineEnc  SourceEnc  DestinationEnc  \
# 0                  5           13           1          3               0
# 1                  9            4           4          2               1
# 2                 18           23           3          3               0
# 3                 16           21           3          0               5
# 4                  9           11           8          3               0
# ...              ...          ...         ...        ...             ...
# 10535             19           22           0          3               0
# 10536             20           23           1          3               0
# 10537              8           11           4          0               2
# 10538             11           14          10          0               5
# 10539             10           19           1          2               1
#
#        AdditionalInfoEnc  MealIncludedEnc  DepDayEnc  ArrivDayEnc  \
# 0                      7                1          0            4
# 1                      7                1          2            0
# 2                      7                1          1            3
# 3                      7                1          1            3
# 4                      7                1          2            2
# ...                  ...              ...        ...          ...
# 10535                  7                1          3            3
# 10536                  7                1          3            3
# 10537                  7                1          2            2
# 10538                  7                1          2            4
# 10539                  7                1          2            3
#
#        FlightLengthEnc
# 0                    1
# 1                    0
# 2                    1
# 3                    1
# 4                    2
# ...                ...
# 10535                2
# 10536                2
# 10537                1
# 10538                2
# 10539                1
#
# [10540 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size = 0.25,shuffle = True , random_state = 44)

X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((7905, 14), (2635, 14), (7905,), (2635,))

# %%
from sklearn.linear_model import LinearRegression,SGDRegressor,Lasso,Ridge
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,median_absolute_error 

LinearRegressionModel = LinearRegression(fit_intercept=True, normalize=True,copy_X=True,n_jobs=-1)
SGDRegressionModel = SGDRegressor(alpha=0.1,random_state=33,penalty='l2',loss = 'huber')
LassoRegressionModel = Lasso(alpha=1.0,random_state=33,normalize=False)
RidgeRegressionModel = Ridge(alpha=1.0,random_state=33)
RandomForestRegressorModel = RandomForestRegressor(n_estimators=1000,max_depth=8, random_state=33)
GBRModel = GradientBoostingRegressor(n_estimators=500,max_depth=7,learning_rate = 1.5 ,random_state=33)
SVRModel = SVR(C = 1.0 ,epsilon=0.1,kernel = 'rbf') 
DecisionTreeRegressorModel = DecisionTreeRegressor( max_depth=3,random_state=33)
KNeighborsRegressorModel = KNeighborsRegressor(n_neighbors = 5, weights='uniform',algorithm = 'auto')    


Models = [LinearRegressionModel,SGDRegressionModel,LassoRegressionModel,RidgeRegressionModel,RandomForestRegressorModel,
          GBRModel,SVRModel,DecisionTreeRegressorModel,KNeighborsRegressorModel]

# %%
for Model in Models : 
    print(f'for Model {str(Model).split("(")[0]}')
    Model.fit(X_train, y_train)
    print(f'Train Score is : {Model.score(X_train, y_train)}')
    print(f'Test Score is : {Model.score(X_test, y_test)}')
    y_pred = Model.predict(X_test)
    print(f'MAE value is  : {mean_absolute_error(y_test, y_pred)}')
    print(f'MSE value is  : {mean_squared_error(y_test, y_pred)}')
    print(f'MdSE value is  : {median_absolute_error(y_test, y_pred)}')
    print('=================================================')
# Out:
# for Model LinearRegression
# Train Score is : 0.4775435721590313
# Test Score is : 0.4910747444977117
# MAE value is  : 2348.009410510438
# MSE value is  : 9482944.967448851
# MdSE value is  : 1933.4450625718328
# =================================================
# for Model SGDRegressor
# Train Score is : -0.34121647825491275
# Test Score is : -0.3704092607956637
# MAE value is  : 3964.3075928041058
# MSE value is  : 25535214.577200536
# MdSE value is  : 2974.772098653234
# =================================================
# for Model Lasso
# Train Score is : 0.4775398346163826
# Test Score is : 0.4911929599644921
# MAE value is  : 2347.5065289052122
# MSE value is  : 9480742.225978155
# MdSE value is  : 1933.1597395154167
# =================================================
# for Model Ridge
# Train Score is : 0.4775432967987898
# Test Score is : 0.4911077723023163
# MAE value is  : 2347.896100130014
# MSE value is  : 9482329.551235814
# MdSE value is  : 1935.0759379330175
# =================================================
# for Model RandomForestRegressor
# C:\Users\User\AppData\anaconda\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# C:\Users\User\AppData\anaconda\lib\site-packages\sklearn\linear_model\_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# Train Score is : 0.8854897897961012
# Test Score is : 0.831247989774579
# MAE value is  : 1114.5458613588278
# MSE value is  : 3144402.854471501
# MdSE value is  : 721.1112509484228
# =================================================
# for Model GradientBoostingRegressor
# Train Score is : 0.9957645205527272
# Test Score is : 0.7184773159567559
# MAE value is  : 1289.5096080523058
# MSE value is  : 5245689.9927981105
# MdSE value is  : 714.6003862122334
# =================================================
# for Model SVR
# Train Score is : 0.14774064858876534
# Test Score is : 0.19402979197981418
# MAE value is  : 2980.1397916178626
# MSE value is  : 15017865.679539576
# MdSE value is  : 2553.3068528618724
# =================================================
# for Model DecisionTreeRegressor
# Train Score is : 0.542581281950764
# Test Score is : 0.5751718551306539
# MAE value is  : 1887.0957185369543
# MSE value is  : 7915940.258149131
# MdSE value is  : 1282.6036484245433
# =================================================
# for Model KNeighborsRegressor
# Train Score is : 0.7047393829250137
# Test Score is : 0.5713925437405293
# MAE value is  : 1810.095787476281
# MSE value is  : 7986361.211992409
# MdSE value is  : 1183.8000000000002
# =================================================

# %%
from sklearn.model_selection import GridSearchCV
import pandas as pd

SelectedModel = RandomForestRegressor(random_state=33)
SelectedParameters = {'n_estimators':[100,200,500,1000],'max_depth':[2,4,8,10]}



GridSearchModel = GridSearchCV(SelectedModel,SelectedParameters,
                               cv = 2,return_train_score=True)
GridSearchModel.fit(X_train, y_train)
sorted(GridSearchModel.cv_results_.keys())
GridSearchResults = pd.DataFrame(GridSearchModel.cv_results_)[
    ['mean_test_score','std_test_score','params','rank_test_score','mean_fit_time']]

# Showing Results
print('All Results are :\n', GridSearchResults )
print('Best Score is :', GridSearchModel.best_score_)
print('Best Parameters are :', GridSearchModel.best_params_)
print('Best Estimator is :', GridSearchModel.best_estimator_)
# Out:
# All Results are :
#      mean_test_score  std_test_score                                   params  \
# 0          0.458371        0.022505    {'max_depth': 2, 'n_estimators': 100}
# 1          0.457557        0.020504    {'max_depth': 2, 'n_estimators': 200}
# 2          0.454872        0.017608    {'max_depth': 2, 'n_estimators': 500}
# 3          0.455927        0.018540   {'max_depth': 2, 'n_estimators': 1000}
# 4          0.626189        0.003478    {'max_depth': 4, 'n_estimators': 100}
# 5          0.625980        0.004057    {'max_depth': 4, 'n_estimators': 200}
# 6          0.626556        0.004646    {'max_depth': 4, 'n_estimators': 500}
# 7          0.627794        0.003929   {'max_depth': 4, 'n_estimators': 1000}
# 8          0.798254        0.003801    {'max_depth': 8, 'n_estimators': 100}
# 9          0.799998        0.004054    {'max_depth': 8, 'n_estimators': 200}
# 10         0.799500        0.004813    {'max_depth': 8, 'n_estimators': 500}
# 11         0.799962        0.003969   {'max_depth': 8, 'n_estimators': 1000}
# 12         0.822258        0.008544   {'max_depth': 10, 'n_estimators': 100}
# 13         0.824836        0.009969   {'max_depth': 10, 'n_estimators': 200}
# 14         0.824645        0.010956   {'max_depth': 10, 'n_estimators': 500}
# 15         0.824782        0.009519  {'max_depth': 10, 'n_estimators': 1000}
#
#     rank_test_score  mean_fit_time
# 0                13       0.173539
# 1                14       0.341577
# 2                16       0.845690
# 3                15       1.685378
# 4                11       0.265059
# 5                12       0.523617
# 6                10       1.315295
# 7                 9       2.642093
# 8                 8       0.454102
# 9                 5       0.891700
# 10                7       2.235003
# 11                6       4.480507
# 12                4       0.543121
# 13                1       1.105249
# 14                3       2.751101
# 15                2       5.379707
# Best Score is : 0.824835981826598
# Best Parameters are : {'max_depth': 10, 'n_estimators': 200}
# Best Estimator is : RandomForestRegressor(max_depth=10, n_estimators=200, random_state=33)

# %%
GridSearchModel.best_estimator_
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=200, random_state=33)

# %%
def DurationTime(n) : 
    if 'm' in n and 'h' in n : 
        H = n.split()[0]
        H = H.strip('h')
        
        M = n.split()[1]
        M = M.strip('m')
        return  int(M) + (60*int(H))
    elif 'm' in n and not 'h' in n : 
        M = n.strip('m')
        return  int(M) 
    else : 
        n = n.strip('h')
        return int(n)*60

    
Test['DayOfJourney'] = Test['Date_of_Journey'].apply(lambda x : x.split('/')[0])
Test['MonthOfJourney'] = Test['Date_of_Journey'].apply(lambda x : x.split('/')[1])
Test['ArrivalTime'] = Test['Arrival_Time'].apply(lambda x : x.split()[0])
Test['DurationTime'] = Test['Duration'].apply(lambda x  :DurationTime(x))
Test['StopsCount'] = Test['Route'].apply(lambda x : x.count('→')-1)
Test['Meal Included'] = Test['Additional_Info'].apply(lambda x : 1 if 
                                                      x !='In-flight meal not included' else 0 )
Test['Additional_Info'].replace('No Info','No info',inplace=True)
Test['DepartureDayPart'] =Test['Dep_Time'].apply(lambda x : DayPart(x))
Test['ArrivalDayPart'] = Test['ArrivalTime'].apply(lambda x : DayPart(x))
Test['FlightLength'] = Test['DurationTime'].apply(lambda x : FlightLength(x))
Test['DepartureHour'] = Test['Dep_Time'].apply(lambda x : x.split(':')[0])
Test['ArrivalHour'] = Test['ArrivalTime'].apply(lambda x : x.split(':')[0])

Test.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info
#
#   DayOfJourney MonthOfJourney ArrivalTime  DurationTime  StopsCount  \
# 0            6             06       04:25           655           1
# 1           12             05       10:20           240           1
# 2           21             05       19:00          1425           1
# 3           21             05       21:00           780           1
# 4           24             06       02:45           170           0
#
#    Meal Included DepartureDayPart ArrivalDayPart FlightLength DepartureHour  \
# 0              1          Evening  Early Morning         Long            17
# 1              1          Morning        Morning       Medium            06
# 2              0            Night          Night         Long            19
# 3              1          Morning          Night         Long            08
# 4              1            Night  Early Morning        Short            23
#
#   ArrivalHour
# 0          04
# 1          10
# 2          19
# 3          21
# 4          02

# %%
def ApplyTestEncoder(Encoder,OriginalColumn) : 
    global Test
    return Encoder.transform(Test[OriginalColumn])


# AirLineEnc,SourceEnc,DestinationEnc,AdditionalInfoEnc,MealIncludedEnc,DepDayEnc,ArrivDayEnc,FlightLengthEnc = LabelEncoder(),LabelEncoder(),LabelEncoder(),LabelEncoder(),LabelEncoder(),LabelEncoder(),LabelEncoder(),LabelEncoder()



Test['AirlineEnc'] = ApplyTestEncoder(AirLineEnc,'Airline')
Test['SourceEnc'] = ApplyTestEncoder(SourceEnc,'Source')
Test['DestinationEnc'] = ApplyTestEncoder(DestinationEnc,'Destination')
Test['AdditionalInfoEnc'] = ApplyTestEncoder(AdditionalInfoEnc,'Additional_Info')
Test['MealIncludedEnc'] = ApplyTestEncoder(MealIncludedEnc,'Meal Included')
Test['DepartureDayPartEnc'] = ApplyTestEncoder(DepDayEnc,'DepartureDayPart')
Test['ArrivalDayPartEnc'] = ApplyTestEncoder(ArrivDayEnc,'ArrivalDayPart')
Test['FlightLengthEnc'] = ApplyTestEncoder(FlightLengthEnc,'FlightLength')
Test.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info
#
#   DayOfJourney MonthOfJourney ArrivalTime  DurationTime  StopsCount  \
# 0            6             06       04:25           655           1
# 1           12             05       10:20           240           1
# 2           21             05       19:00          1425           1
# 3           21             05       21:00           780           1
# 4           24             06       02:45           170           0
#
#    Meal Included DepartureDayPart ArrivalDayPart FlightLength DepartureHour  \
# 0              1          Evening  Early Morning         Long            17
# 1              1          Morning        Morning       Medium            06
# 2              0            Night          Night         Long            19
# 3              1          Morning          Night         Long            08
# 4              1            Night  Early Morning        Short            23
#
#   ArrivalHour  AirlineEnc  SourceEnc  DestinationEnc  AdditionalInfoEnc  \
# 0          04           4          2               1                  7
# 1          10           3          3               0                  7
# 2          19           4          2               1                  5
# 3          21           6          2               1                  7
# 4          02           0          0               2                  7
#
#    MealIncludedEnc  DepartureDayPartEnc  ArrivalDayPartEnc  FlightLengthEnc
# 0                1                    1                  0                0
# 1                1                    2                  2                1
# 2                0                    3                  3                0
# 3                1                    2                  3                0
# 4                1                    3                  0                2

# %%
Test.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'DayOfJourney', 'MonthOfJourney', 'ArrivalTime',
#        'DurationTime', 'StopsCount', 'Meal Included', 'DepartureDayPart',
#        'ArrivalDayPart', 'FlightLength', 'DepartureHour', 'ArrivalHour',
#        'AirlineEnc', 'SourceEnc', 'DestinationEnc', 'AdditionalInfoEnc',
#        'MealIncludedEnc', 'DepartureDayPartEnc', 'ArrivalDayPartEnc',
#        'FlightLengthEnc'],
#       dtype='object')

# %%
ColumnsToInt = ['DayOfJourney','MonthOfJourney','DurationTime','StopsCount',
                'Meal Included','DepartureHour','ArrivalHour'] 
for col in ColumnsToInt : 
    Test[col]  =Test[col].astype(int)
Test.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info
#
#    DayOfJourney  MonthOfJourney ArrivalTime  DurationTime  StopsCount  \
# 0             6               6       04:25           655           1
# 1            12               5       10:20           240           1
# 2            21               5       19:00          1425           1
# 3            21               5       21:00           780           1
# 4            24               6       02:45           170           0
#
#    Meal Included DepartureDayPart ArrivalDayPart FlightLength  DepartureHour  \
# 0              1          Evening  Early Morning         Long             17
# 1              1          Morning        Morning       Medium              6
# 2              0            Night          Night         Long             19
# 3              1          Morning          Night         Long              8
# 4              1            Night  Early Morning        Short             23
#
#    ArrivalHour  AirlineEnc  SourceEnc  DestinationEnc  AdditionalInfoEnc  \
# 0            4           4          2               1                  7
# 1           10           3          3               0                  7
# 2           19           4          2               1                  5
# 3           21           6          2               1                  7
# 4            2           0          0               2                  7
#
#    MealIncludedEnc  DepartureDayPartEnc  ArrivalDayPartEnc  FlightLengthEnc
# 0                1                    1                  0                0
# 1                1                    2                  2                1
# 2                0                    3                  3                0
# 3                1                    2                  3                0
# 4                1                    3                  0                2

# %%
Test.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'DayOfJourney', 'MonthOfJourney', 'ArrivalTime',
#        'DurationTime', 'StopsCount', 'Meal Included', 'DepartureDayPart',
#        'ArrivalDayPart', 'FlightLength', 'DepartureHour', 'ArrivalHour',
#        'AirlineEnc', 'SourceEnc', 'DestinationEnc', 'AdditionalInfoEnc',
#        'MealIncludedEnc', 'DepartureDayPartEnc', 'ArrivalDayPartEnc',
#        'FlightLengthEnc'],
#       dtype='object')

# %%
X = Test[['DayOfJourney','MonthOfJourney','DurationTime','StopsCount',
          'Meal Included','DepartureHour','ArrivalHour', 'AirlineEnc', 'SourceEnc','DestinationEnc', 
          'AdditionalInfoEnc', 'DepartureDayPartEnc', 'ArrivalDayPartEnc', 'FlightLengthEnc']]

# %%
Results = GridSearchModel.best_estimator_.predict(X)
# Out:
# C:\Users\User\AppData\anaconda\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - AirlineEnc
# - ArrivalDayPartEnc
# - DepartureDayPartEnc
# - DurationTime
# - Meal Included
# Feature names seen at fit time, yet now missing:
# - AirLineEnc
# - ArrivDayEnc
# - DepDayEnc
# - DurationInMinutes
# - MealIncludedEnc
#
#   warnings.warn(message, FutureWarning)

# %%
Results = [np.round(i) for i in Results]
Results
# Out:
# [16463.0,
#  28965.0,
#  15621.0,
#  16757.0,
#  27144.0,
#  15222.0,
#  11331.0,
#  32865.0,
#  28022.0,
#  22971.0,
#  16540.0,
#  16445.0,
#  16499.0,
#  8435.0,
#  15532.0,
#  13560.0,
#  15997.0,
#  17673.0,
#  16897.0,
#  11813.0,
#  14196.0,
#  16671.0,
#  11222.0,
#  21053.0,
#  28163.0,
#  15968.0,
#  27800.0,
#  15237.0,
#  16933.0,
#  19128.0,
#  28491.0,
#  10781.0,
#  23967.0,
#  29004.0,
#  26095.0,
#  26767.0,
#  26048.0,
#  12799.0,
#  15970.0,
#  16502.0,
#  27549.0,
#  9992.0,
#  26405.0,
#  17493.0,
#  28316.0,
#  28556.0,
#  19214.0,
#  26427.0,
#  20527.0,
#  16767.0,
#  19757.0,
#  37173.0,
#  16879.0,
#  10027.0,
#  27160.0,
